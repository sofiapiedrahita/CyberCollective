# %%
from IPython.display import Image
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
sns.set(rc={'figure.figsize':(6,8)}) 

import warnings
warnings.simplefilter("ignore")

# %matplotlib inline

from sklearn.preprocessing import LabelEncoder 

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

from sklearn import metrics

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate

from sklearn.metrics import SCORERS
import re

import nltk 
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %% [markdown]
# # Cyber Security Tweets | Elyse

# %%
data = pd.read_csv('cybersecurity_tweets.csv')

# %%
data.head()
# Out:
#       user_id             status_id           created_at  screen_name  \
# 0  x109082290  x1404488925935177737  2021-06-14 17:20:28  NcsVentures
# 1  x109082290  x1403635112613494786  2021-06-12 08:47:43  NcsVentures
# 2  x109082290  x1403747937818120198  2021-06-12 16:16:03  NcsVentures
# 3  x109082290  x1404021845913899009  2021-06-13 10:24:28  NcsVentures
# 4  x109082290  x1404053089804554241  2021-06-13 12:28:37  NcsVentures
#
#                                                                                                                                                                                                                                  text  \
# 0  Signs, Causes and Solutions for Network Data Breaches | #cybersecurity | #cyberattack https://t.co/oxotVQ4ogO
# 1  Battling Chinese Big Tech encroachment in India | #cybersecurity | #cyberattack https://t.co/GFXaut9ZXH
# 2  Ask Dr. Jeanette® Success On “The Way” Devil On A Choke Chain! It’s Gonna Be Quick! It’s Gonna Be Sure! It’s Gonna Be Final! – Los Angeles Sentinel | Los Angeles Sentinel | #cybersecurity | #cyberattack https://t.co/0yfsRAdUMk
# 3  Cyber threats to Digital Pakistan | #cybersecurity | #cyberattack https://t.co/Se4ENqeOQT
# 4  Pakistan Cyber Attack News: Pakistan army claims major cyber attack by Indian intel | World News | #cybersecurity | #cyberattack https://t.co/wsnAO20OiG
#
#           source  display_text_width reply_to_status_id reply_to_user_id  \
# 0  WordPress.com  109                 NaN                NaN
# 1  WordPress.com  103                 NaN                NaN
# 2  WordPress.com  226                 NaN                NaN
# 3  WordPress.com  89                  NaN                NaN
# 4  WordPress.com  152                 NaN                NaN
#
#   reply_to_screen_name  ...  statuses_count  favourites_count  \
# 0  NaN                  ...  260725          0
# 1  NaN                  ...  260725          0
# 2  NaN                  ...  260725          0
# 3  NaN                  ...  260725          0
# 4  NaN                  ...  260725          0
#
#     account_created_at  verified              profile_url  \
# 0  2010-01-27 22:48:24  False     https://t.co/E0XpJWVD52
# 1  2010-01-27 22:48:24  False     https://t.co/E0XpJWVD52
# 2  2010-01-27 22:48:24  False     https://t.co/E0XpJWVD52
# 3  2010-01-27 22:48:24  False     https://t.co/E0XpJWVD52
# 4  2010-01-27 22:48:24  False     https://t.co/E0XpJWVD52
#
#                     profile_expanded_url account_lang  \
# 0  http://www.nationalcybersecurity.com/ NaN
# 1  http://www.nationalcybersecurity.com/ NaN
# 2  http://www.nationalcybersecurity.com/ NaN
# 3  http://www.nationalcybersecurity.com/ NaN
# 4  http://www.nationalcybersecurity.com/ NaN
#
#                                            profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/109082290/1488488011
# 1  https://pbs.twimg.com/profile_banners/109082290/1488488011
# 2  https://pbs.twimg.com/profile_banners/109082290/1488488011
# 3  https://pbs.twimg.com/profile_banners/109082290/1488488011
# 4  https://pbs.twimg.com/profile_banners/109082290/1488488011
#
#                               profile_background_url  \
# 0  http://abs.twimg.com/images/themes/theme15/bg.png
# 1  http://abs.twimg.com/images/themes/theme15/bg.png
# 2  http://abs.twimg.com/images/themes/theme15/bg.png
# 3  http://abs.twimg.com/images/themes/theme15/bg.png
# 4  http://abs.twimg.com/images/themes/theme15/bg.png
#
#                                                     profile_image_url
# 0  http://pbs.twimg.com/profile_images/715854922/ncsavatar_normal.png
# 1  http://pbs.twimg.com/profile_images/715854922/ncsavatar_normal.png
# 2  http://pbs.twimg.com/profile_images/715854922/ncsavatar_normal.png
# 3  http://pbs.twimg.com/profile_images/715854922/ncsavatar_normal.png
# 4  http://pbs.twimg.com/profile_images/715854922/ncsavatar_normal.png
#
# [5 rows x 90 columns]

# %%
data.columns
# Out:
# Index(['user_id', 'status_id', 'created_at', 'screen_name', 'text', 'source',
#        'display_text_width', 'reply_to_status_id', 'reply_to_user_id',
#        'reply_to_screen_name', 'is_quote', 'is_retweet', 'favorite_count',
#        'retweet_count', 'quote_count', 'reply_count', 'hashtags', 'symbols',
#        'urls_url', 'urls_t.co', 'urls_expanded_url', 'media_url', 'media_t.co',
#        'media_expanded_url', 'media_type', 'ext_media_url', 'ext_media_t.co',
#        'ext_media_expanded_url', 'ext_media_type', 'mentions_user_id',
#        'mentions_screen_name', 'lang', 'quoted_status_id', 'quoted_text',
#        'quoted_created_at', 'quoted_source', 'quoted_favorite_count',
#        'quoted_retweet_count', 'quoted_user_id', 'quoted_screen_name',
#        'quoted_name', 'quoted_followers_count', 'quoted_friends_count',
#        'quoted_statuses_count', 'quoted_location', 'quoted_description',
#        'quoted_verified', 'retweet_status_id', 'retweet_text',
#        'retweet_created_at', 'retweet_source', 'retweet_favorite_count',
#        'retweet_retweet_count', 'retweet_user_id', 'retweet_screen_name',
#        'retweet_name', 'retweet_followers_count', 'retweet_friends_count',
#        'retweet_statuses_count', 'retweet_location', 'retweet_description',
#        'retweet_verified', 'place_url', 'place_name', 'place_full_name',
#        'place_type', 'country', 'country_code', 'geo_coords', 'coords_coords',
#        'bbox_coords', 'status_url', 'name', 'location', 'description', 'url',
#        'protected', 'followers_count', 'friends_count', 'listed_count',
#        'statuses_count', 'favourites_count', 'account_created_at', 'verified',
#        'profile_url', 'profile_expanded_url', 'account_lang',
#        'profile_banner_url', 'profile_background_url', 'profile_image_url'],
#       dtype='object')

# %%
df = data[["text", "is_quote", "is_retweet", "retweet_count", "hashtags", "followers_count"]]

# %%
cyber = df[["text"]][:1000]
pd.set_option('display.max_colwidth', -1)
cyber.head()
# Out:
#                                                                                                                                                                                                                                  text
# 0  Signs, Causes and Solutions for Network Data Breaches | #cybersecurity | #cyberattack https://t.co/oxotVQ4ogO
# 1  Battling Chinese Big Tech encroachment in India | #cybersecurity | #cyberattack https://t.co/GFXaut9ZXH
# 2  Ask Dr. Jeanette® Success On “The Way” Devil On A Choke Chain! It’s Gonna Be Quick! It’s Gonna Be Sure! It’s Gonna Be Final! – Los Angeles Sentinel | Los Angeles Sentinel | #cybersecurity | #cyberattack https://t.co/0yfsRAdUMk
# 3  Cyber threats to Digital Pakistan | #cybersecurity | #cyberattack https://t.co/Se4ENqeOQT
# 4  Pakistan Cyber Attack News: Pakistan army claims major cyber attack by Indian intel | World News | #cybersecurity | #cyberattack https://t.co/wsnAO20OiG

# %% [markdown]
# ## Cleaning Data

# %%
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
wnet = WordNetLemmatizer()
port = PorterStemmer()

# %%
def cleanTxt(txt):
    txt = txt.lower()
    txt = re.sub(r'RT[\s]+', '', txt) #removing RT
    txt = re.sub(r'[^\w\s]','', txt) #remove everything except words and space
    txt = re.sub(r'_','', txt) #how to remove underscore as well
    if 'https' in txt: # removing hyperlinks 
        pos = txt.find('https')
        txt = txt[:pos]
    return txt

# %%
cyber['text'] = cyber['text'].apply(cleanTxt)
cyber.head()
# Out:
#                                                                                                                                                         text
# 0  sign cause solution network data breach  cybersecurity  cyberattack
# 1  battling chinese big tech encroachment india  cybersecurity  cyberattack
# 2  ask dr jeanette success way devil choke chain gonna quick gonna sure gonna final  los angeles sentinel  los angeles sentinel  cybersecurity  cyberattack
# 3  cyber threat digital pakistan  cybersecurity  cyberattack
# 4  pakistan cyber attack news pakistan army claim major cyber attack indian intel  world news  cybersecurity  cyberattack

# %%
def stopWords(txt): 
    txt_lst = txt.split(" ")
    txt_lst = [word for word in txt_lst if word not in stopwords.words('english')]
    txt_lst = [wnet.lemmatize(word) for word in txt_lst]
    return " ".join(txt_lst)

# %%
cyber['text'] = cyber['text'].apply(stopWords)
cyber.head()
# Out:
#                                                                                                                                                         text
# 0  sign cause solution network data breach  cybersecurity  cyberattack
# 1  battling chinese big tech encroachment india  cybersecurity  cyberattack
# 2  ask dr jeanette success way devil choke chain gonna quick gonna sure gonna final  los angeles sentinel  los angeles sentinel  cybersecurity  cyberattack
# 3  cyber threat digital pakistan  cybersecurity  cyberattack
# 4  pakistan cyber attack news pakistan army claim major cyber attack indian intel  world news  cybersecurity  cyberattack

# %%
cs_words = []

for row in cyber['text']:
    for word in str(row).split(" "):
        cs_words.append(word)
        
cs_words
# Out:
# ['sign',
#  'cause',
#  'solution',
#  'network',
#  'data',
#  'breach',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'battling',
#  'chinese',
#  'big',
#  'tech',
#  'encroachment',
#  'india',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'ask',
#  'dr',
#  'jeanette',
#  'success',
#  'way',
#  'devil',
#  'choke',
#  'chain',
#  'gonna',
#  'quick',
#  'gonna',
#  'sure',
#  'gonna',
#  'final',
#  '',
#  'los',
#  'angeles',
#  'sentinel',
#  '',
#  'los',
#  'angeles',
#  'sentinel',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'cyber',
#  'threat',
#  'digital',
#  'pakistan',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'pakistan',
#  'cyber',
#  'attack',
#  'news',
#  'pakistan',
#  'army',
#  'claim',
#  'major',
#  'cyber',
#  'attack',
#  'indian',
#  'intel',
#  '',
#  'world',
#  'news',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'reimagining',
#  'cyber',
#  'conflict',
#  'prospect',
#  'tech',
#  'cold',
#  'war',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'jill',
#  'biden',
#  'meet',
#  'uk',
#  'military',
#  'veteran',
#  'group',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'politico',
#  'playbook',
#  'conservative',
#  'make',
#  'case',
#  'overhauling',
#  'filibuster',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'pak',
#  'cyber',
#  'security',
#  'cyber',
#  'crime',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'indian',
#  'agency',
#  'start',
#  'countering',
#  'paks',
#  'cyber',
#  'warfare',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'update',
#  'window',
#  'computer',
#  'patch',
#  '6',
#  'new',
#  'inthewild',
#  'zeroday',
#  'bug',
#  '',
#  'microsoft',
#  '',
#  'hacking',
#  '\xa0cybersecurity',
#  '',
#  'impose',
#  'ban',
#  'bitcoin',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'miss',
#  'trump',
#  'lindsey',
#  'graham',
#  'slam',
#  'biden',
#  'foreign',
#  'policy',
#  'alleges',
#  'bad',
#  'guy',
#  'afraid',
#  'former',
#  'president',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'meat',
#  'giant',
#  'jbs',
#  'fully',
#  'operational',
#  'ransomware',
#  'attack',
#  '',
#  'microsoft',
#  '',
#  'hacking',
#  '\xa0cybersecurity',
#  '',
#  '5',
#  'book',
#  'bill',
#  'gate',
#  'recommends',
#  'summer',
#  'reading',
#  '',
#  'microsoft',
#  '',
#  'hacking',
#  '\xa0cybersecurity',
#  '',
#  'mercenary',
#  'hacker',
#  'group',
#  'widespread',
#  'mideast',
#  'research',
#  'find',
#  '',
#  'cybersecurity',
#  'news',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'biden',
#  'nato',
#  'ready',
#  'talk',
#  'china',
#  'russia',
#  'soothe',
#  'ally',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'govt',
#  'dismisses',
#  'claim',
#  'cowin',
#  'system',
#  'hack',
#  'say',
#  'rumour',
#  'data',
#  'leak',
#  'baseless',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'scammer',
#  'always',
#  'ask',
#  'gift',
#  'card',
#  '',
#  'microsoft',
#  '',
#  'hacking',
#  '\xa0cybersecurity',
#  '',
#  'joe',
#  'biden',
#  'unlike',
#  'predecessor',
#  'maintained',
#  'putin',
#  'skepticism',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'scam',
#  'alert',
#  'chinese',
#  'hacker',
#  'luring',
#  'indian',
#  'fake',
#  'tata',
#  'motor',
#  'gift',
#  'campaign',
#  'collect',
#  'user',
#  'data',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'mr',
#  'robot',
#  'christian',
#  'slater',
#  'warns',
#  'hacking',
#  'danger',
#  'hp',
#  'campaign',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'u',
#  'need',
#  'boost',
#  'cyber',
#  'security',
#  'cyber',
#  'warfare',
#  'age',
#  '',
#  'albuquerque',
#  'journal',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'hackersera',
#  'wellknown',
#  'cybersecurity',
#  'company',
#  'based',
#  'india',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'uk',
#  'tell',
#  'un',
#  'nationstates',
#  'retaliate',
#  'cyber',
#  'badness',
#  'warning',
#  '',
#  'register',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'window',
#  '10',
#  'builtin',
#  'ransomware',
#  'protection',
#  'use',
#  '',
#  'microsoft',
#  '',
#  'hacking',
#  '\xa0cybersecurity',
#  '',
#  'proposed',
#  'medium',
#  'law',
#  'pakistan',
#  'journalist',
#  'boil',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'bidens',
#  'executive',
#  'order',
#  'could',
#  'impact',
#  'foreignowned',
#  'apps',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'car',
#  'bombing',
#  'hotel',
#  'southwest',
#  'pakistan',
#  'kill',
#  '4',
#  'wound',
#  '11',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'microsoft',
#  'say',
#  'found',
#  'malicious',
#  'software',
#  'system',
#  '',
#  'microsoft',
#  '',
#  'hacking',
#  '\xa0cybersecurity',
#  '',
#  'terror',
#  'child',
#  'mus',
#  '',
#  'architecture',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'v',
#  'raghunandan',
#  'take',
#  'new',
#  'trai',
#  'secretary',
#  'gupta',
#  'oversee',
#  'lsas',
#  'telecom',
#  'news',
#  'et',
#  'telecom',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'business',
#  'news',
#  '',
#  'stock',
#  'share',
#  'market',
#  'news',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'pakistani',
#  'electric',
#  'supply',
#  'company',
#  'struck',
#  'netwalker',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'excuse',
#  'happened',
#  'resilience',
#  'tough',
#  'failure',
#  'due',
#  'sequence',
#  'event',
#  'almost',
#  'impossible',
#  'foresee',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'cyberattacksfrequency',
#  'sign',
#  'red',
#  'alert',
#  'india',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'colonial',
#  'pipeline',
#  'paid',
#  '5m',
#  'ransom',
#  'hacking',
#  'group',
#  'darkside',
#  'huge',
#  'attack',
#  'report',
#  'say',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'whatsapp',
#  'user',
#  'pakistan',
#  'beware',
#  'new',
#  'simple',
#  'hacker',
#  'trick',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'colonial',
#  'pipeline',
#  'reaching',
#  'full',
#  'capacity',
#  'cyberattack',
#  'biden',
#  'say',
#  '',
#  'u',
#  'news',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'attack',
#  'asad',
#  'toor',
#  'press',
#  'freedom',
#  'medium',
#  'law',
#  'pakistan',
#  '',
#  'analysis',
#  '',
#  'eurasia',
#  'review',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'swiss',
#  'authority',
#  'raid',
#  'home',
#  'hacker',
#  'potentially',
#  'responsible',
#  'breaching',
#  'surveillance',
#  'camera',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'uk',
#  'competition',
#  'bod',
#  'keep',
#  'tab',
#  'google',
#  'ensure',
#  'privacy',
#  'sandbox',
#  'doesnt',
#  'distort',
#  'competition',
#  '',
#  'register',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'unexpected',
#  'growth',
#  'seen',
#  'global',
#  'cybersecurity',
#  'market',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'warzone',
#  'hacker',
#  'openly',
#  'cheat',
#  'live',
#  'twitch',
#  'justifies',
#  'action',
#  'angry',
#  'twitch',
#  'chat',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'u',
#  'expose',
#  'hacker',
#  'helper',
#  'punish',
#  'russian',
#  'attack',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'israel',
#  'arm',
#  'security',
#  'industry',
#  'reshaping',
#  'state',
#  'violence',
#  'everywhere',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'window',
#  '10',
#  'update',
#  'kb5003637',
#  'cause',
#  'taskbarsystem',
#  'tray',
#  'amp',
#  'printer',
#  'issue',
#  'fails',
#  'install',
#  'many',
#  '',
#  'microsoft',
#  '',
#  'hacking',
#  '\xa0cybersecurity',
#  '',
#  'reviving',
#  'nato',
#  'report',
#  'brain',
#  'death',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'aws',
#  'frankfurt',
#  'experience',
#  'major',
#  'breakdown',
#  'staff',
#  'couldnt',
#  'fix',
#  'hour',
#  'due',
#  'environmental',
#  'condition',
#  'data',
#  'centre',
#  'floor',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'new',
#  'york',
#  'state',
#  'senate',
#  'first',
#  'pas',
#  'landmark',
#  'righttorepair',
#  'bill',
#  '',
#  'dont',
#  'go',
#  'popping',
#  'champagne',
#  'yet',
#  '',
#  'register',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'u',
#  'recovers',
#  '44m',
#  'ransom',
#  'paid',
#  'darkside',
#  'colonial',
#  'pipeline',
#  'hack',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'slk',
#  'software',
#  'optimising',
#  'performance',
#  'digital',
#  'economy',
#  '',
#  'technology',
#  'amp',
#  'ai',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'pipeline',
#  'hack',
#  'point',
#  'growing',
#  'cybersecurity',
#  'risk',
#  'energy',
#  'system',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'ubisoft',
#  'forward',
#  '',
#  'watch',
#  'publisher',
#  'demo',
#  'e3',
#  '2021',
#  'u',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'day',
#  '',
#  'hacker',
#  'known',
#  'max',
#  '55yearold',
#  'woman',
#  'russia',
#  'u',
#  'say',
#  '',
#  'microsoft',
#  '',
#  'hacking',
#  '\xa0cybersecurity',
#  '',
#  'cybersecurity',
#  'service',
#  'market',
#  'size',
#  'growth',
#  '20212027',
#  '',
#  'microsoft',
#  '',
#  'hacking',
#  '\xa0cybersecurity',
#  '',
#  'trump',
#  'twitter',
#  'hack',
#  'police',
#  'accept',
#  'attacker',
#  'claim',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'report',
#  'telecom',
#  'news',
#  'et',
#  'telecom',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'coronavirus',
#  'live',
#  'india',
#  'see',
#  '80834',
#  'new',
#  'case',
#  'lowest',
#  'spike',
#  '71',
#  'day',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'ransomware',
#  'cartel',
#  'using',
#  'new',
#  'tactic',
#  'extort',
#  'money',
#  '',
#  'microsoft',
#  '',
#  'hacking',
#  '\xa0cybersecurity',
#  '',
#  'communicate',
#  'safely',
#  'lifetime',
#  'encrypted',
#  'email',
#  '200',
#  '',
#  'microsoft',
#  '',
#  'hacking',
#  '\xa0cybersecurity',
#  '',
#  'source',
#  'telecom',
#  'news',
#  'et',
#  'telecom',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'weve',
#  'shown',
#  'time',
#  'strong',
#  'encryption',
#  'put',
#  'crims',
#  'behind',
#  'bar',
#  'politico',
#  'hate',
#  '',
#  'register',
#  '',
#  'microsoft',
#  '',
#  'hacking',
#  '\xa0cybersecurity',
#  '',
#  'chinese',
#  'hacker',
#  'target',
#  'indian',
#  'vaccine',
#  'maker',
#  'sii',
#  'bharat',
#  'biotech',
#  'say',
#  'security',
#  'firm',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'foreignbound',
#  'student',
#  'welcome',
#  'relaxation',
#  '2nd',
#  'vaccine',
#  'dose',
#  'gap',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'energy',
#  'relation',
#  'sign',
#  'russia',
#  'declining',
#  'global',
#  'standing',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'asiapakistan',
#  '',
#  'fake',
#  'news',
#  'rape',
#  'religious',
#  'conversion',
#  'christian',
#  'girl',
#  'attack',
#  'church',
#  'damage',
#  'religious',
#  'minority',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'hacker',
#  'stealing',
#  'money',
#  'via',
#  '167',
#  'fake',
#  'trading',
#  'crypto',
#  'apps',
#  'android',
#  'io',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'coronavirus',
#  'african',
#  'sex',
#  'worker',
#  'lack',
#  'food',
#  'hiv',
#  'drug',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'indian',
#  'court',
#  'reject',
#  'plea',
#  'amazon',
#  'flipkart',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'ireland',
#  'warned',
#  'could',
#  'face',
#  'rolling',
#  'blackout',
#  'doesnt',
#  'address',
#  'data',
#  'centre',
#  'demand',
#  'electricity',
#  '',
#  'register',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'counterpoint',
#  'telecom',
#  'news',
#  'et',
#  'telecom',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'identity',
#  'authentication',
#  'access',
#  'market',
#  'set',
#  'hit',
#  '285bn',
#  '2021',
#  '',
#  'microsoft',
#  '',
#  'hacking',
#  '\xa0cybersecurity',
#  '',
#  'major',
#  'cyberattacks',
#  'rise',
#  'u',
#  'expert',
#  'say',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'hacker',
#  'deface',
#  'facebooks',
#  'official',
#  'twitter',
#  'instagram',
#  'account',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  '',
#  'health',
#  'ministry',
#  'security',
#  'researcher',
#  'deny',
#  'report',
#  'cowin',
#  'data',
#  'breach',
#  'meity',
#  'investigate',
#  '',
#  'cybersecurity',
#  '\xa0cyberattack',
#  ...]

# %%
len(cs_words)
# Out:
# 13589

# %%
cs_words = [word for word in cs_words if word != '\r\n\r\n'] # indicates space and indexing

# %%
cs_words = [word for word in cs_words if word != 'u0001f449'] # indicates back hand emoji pointing right

# %%
cs_words = [word for word in cs_words if word != ''] # indicates back hand emoji pointing right
cs_words
# Out:
# ['sign',
#  'cause',
#  'solution',
#  'network',
#  'data',
#  'breach',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'battling',
#  'chinese',
#  'big',
#  'tech',
#  'encroachment',
#  'india',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'ask',
#  'dr',
#  'jeanette',
#  'success',
#  'way',
#  'devil',
#  'choke',
#  'chain',
#  'gonna',
#  'quick',
#  'gonna',
#  'sure',
#  'gonna',
#  'final',
#  'los',
#  'angeles',
#  'sentinel',
#  'los',
#  'angeles',
#  'sentinel',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'cyber',
#  'threat',
#  'digital',
#  'pakistan',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'pakistan',
#  'cyber',
#  'attack',
#  'news',
#  'pakistan',
#  'army',
#  'claim',
#  'major',
#  'cyber',
#  'attack',
#  'indian',
#  'intel',
#  'world',
#  'news',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'reimagining',
#  'cyber',
#  'conflict',
#  'prospect',
#  'tech',
#  'cold',
#  'war',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'jill',
#  'biden',
#  'meet',
#  'uk',
#  'military',
#  'veteran',
#  'group',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'politico',
#  'playbook',
#  'conservative',
#  'make',
#  'case',
#  'overhauling',
#  'filibuster',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'pak',
#  'cyber',
#  'security',
#  'cyber',
#  'crime',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'indian',
#  'agency',
#  'start',
#  'countering',
#  'paks',
#  'cyber',
#  'warfare',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'update',
#  'window',
#  'computer',
#  'patch',
#  '6',
#  'new',
#  'inthewild',
#  'zeroday',
#  'bug',
#  'microsoft',
#  'hacking',
#  '\xa0cybersecurity',
#  'impose',
#  'ban',
#  'bitcoin',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'miss',
#  'trump',
#  'lindsey',
#  'graham',
#  'slam',
#  'biden',
#  'foreign',
#  'policy',
#  'alleges',
#  'bad',
#  'guy',
#  'afraid',
#  'former',
#  'president',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'meat',
#  'giant',
#  'jbs',
#  'fully',
#  'operational',
#  'ransomware',
#  'attack',
#  'microsoft',
#  'hacking',
#  '\xa0cybersecurity',
#  '5',
#  'book',
#  'bill',
#  'gate',
#  'recommends',
#  'summer',
#  'reading',
#  'microsoft',
#  'hacking',
#  '\xa0cybersecurity',
#  'mercenary',
#  'hacker',
#  'group',
#  'widespread',
#  'mideast',
#  'research',
#  'find',
#  'cybersecurity',
#  'news',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'biden',
#  'nato',
#  'ready',
#  'talk',
#  'china',
#  'russia',
#  'soothe',
#  'ally',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'govt',
#  'dismisses',
#  'claim',
#  'cowin',
#  'system',
#  'hack',
#  'say',
#  'rumour',
#  'data',
#  'leak',
#  'baseless',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'scammer',
#  'always',
#  'ask',
#  'gift',
#  'card',
#  'microsoft',
#  'hacking',
#  '\xa0cybersecurity',
#  'joe',
#  'biden',
#  'unlike',
#  'predecessor',
#  'maintained',
#  'putin',
#  'skepticism',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'scam',
#  'alert',
#  'chinese',
#  'hacker',
#  'luring',
#  'indian',
#  'fake',
#  'tata',
#  'motor',
#  'gift',
#  'campaign',
#  'collect',
#  'user',
#  'data',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'mr',
#  'robot',
#  'christian',
#  'slater',
#  'warns',
#  'hacking',
#  'danger',
#  'hp',
#  'campaign',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'u',
#  'need',
#  'boost',
#  'cyber',
#  'security',
#  'cyber',
#  'warfare',
#  'age',
#  'albuquerque',
#  'journal',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'hackersera',
#  'wellknown',
#  'cybersecurity',
#  'company',
#  'based',
#  'india',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'uk',
#  'tell',
#  'un',
#  'nationstates',
#  'retaliate',
#  'cyber',
#  'badness',
#  'warning',
#  'register',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'window',
#  '10',
#  'builtin',
#  'ransomware',
#  'protection',
#  'use',
#  'microsoft',
#  'hacking',
#  '\xa0cybersecurity',
#  'proposed',
#  'medium',
#  'law',
#  'pakistan',
#  'journalist',
#  'boil',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'bidens',
#  'executive',
#  'order',
#  'could',
#  'impact',
#  'foreignowned',
#  'apps',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'car',
#  'bombing',
#  'hotel',
#  'southwest',
#  'pakistan',
#  'kill',
#  '4',
#  'wound',
#  '11',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'microsoft',
#  'say',
#  'found',
#  'malicious',
#  'software',
#  'system',
#  'microsoft',
#  'hacking',
#  '\xa0cybersecurity',
#  'terror',
#  'child',
#  'mus',
#  'architecture',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'v',
#  'raghunandan',
#  'take',
#  'new',
#  'trai',
#  'secretary',
#  'gupta',
#  'oversee',
#  'lsas',
#  'telecom',
#  'news',
#  'et',
#  'telecom',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'business',
#  'news',
#  'stock',
#  'share',
#  'market',
#  'news',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'pakistani',
#  'electric',
#  'supply',
#  'company',
#  'struck',
#  'netwalker',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'excuse',
#  'happened',
#  'resilience',
#  'tough',
#  'failure',
#  'due',
#  'sequence',
#  'event',
#  'almost',
#  'impossible',
#  'foresee',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'cyberattacksfrequency',
#  'sign',
#  'red',
#  'alert',
#  'india',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'colonial',
#  'pipeline',
#  'paid',
#  '5m',
#  'ransom',
#  'hacking',
#  'group',
#  'darkside',
#  'huge',
#  'attack',
#  'report',
#  'say',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'whatsapp',
#  'user',
#  'pakistan',
#  'beware',
#  'new',
#  'simple',
#  'hacker',
#  'trick',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'colonial',
#  'pipeline',
#  'reaching',
#  'full',
#  'capacity',
#  'cyberattack',
#  'biden',
#  'say',
#  'u',
#  'news',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'attack',
#  'asad',
#  'toor',
#  'press',
#  'freedom',
#  'medium',
#  'law',
#  'pakistan',
#  'analysis',
#  'eurasia',
#  'review',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'swiss',
#  'authority',
#  'raid',
#  'home',
#  'hacker',
#  'potentially',
#  'responsible',
#  'breaching',
#  'surveillance',
#  'camera',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'uk',
#  'competition',
#  'bod',
#  'keep',
#  'tab',
#  'google',
#  'ensure',
#  'privacy',
#  'sandbox',
#  'doesnt',
#  'distort',
#  'competition',
#  'register',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'unexpected',
#  'growth',
#  'seen',
#  'global',
#  'cybersecurity',
#  'market',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'warzone',
#  'hacker',
#  'openly',
#  'cheat',
#  'live',
#  'twitch',
#  'justifies',
#  'action',
#  'angry',
#  'twitch',
#  'chat',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'u',
#  'expose',
#  'hacker',
#  'helper',
#  'punish',
#  'russian',
#  'attack',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'israel',
#  'arm',
#  'security',
#  'industry',
#  'reshaping',
#  'state',
#  'violence',
#  'everywhere',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'window',
#  '10',
#  'update',
#  'kb5003637',
#  'cause',
#  'taskbarsystem',
#  'tray',
#  'amp',
#  'printer',
#  'issue',
#  'fails',
#  'install',
#  'many',
#  'microsoft',
#  'hacking',
#  '\xa0cybersecurity',
#  'reviving',
#  'nato',
#  'report',
#  'brain',
#  'death',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'aws',
#  'frankfurt',
#  'experience',
#  'major',
#  'breakdown',
#  'staff',
#  'couldnt',
#  'fix',
#  'hour',
#  'due',
#  'environmental',
#  'condition',
#  'data',
#  'centre',
#  'floor',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'new',
#  'york',
#  'state',
#  'senate',
#  'first',
#  'pas',
#  'landmark',
#  'righttorepair',
#  'bill',
#  'dont',
#  'go',
#  'popping',
#  'champagne',
#  'yet',
#  'register',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'u',
#  'recovers',
#  '44m',
#  'ransom',
#  'paid',
#  'darkside',
#  'colonial',
#  'pipeline',
#  'hack',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'slk',
#  'software',
#  'optimising',
#  'performance',
#  'digital',
#  'economy',
#  'technology',
#  'amp',
#  'ai',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'pipeline',
#  'hack',
#  'point',
#  'growing',
#  'cybersecurity',
#  'risk',
#  'energy',
#  'system',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'ubisoft',
#  'forward',
#  'watch',
#  'publisher',
#  'demo',
#  'e3',
#  '2021',
#  'u',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'day',
#  'hacker',
#  'known',
#  'max',
#  '55yearold',
#  'woman',
#  'russia',
#  'u',
#  'say',
#  'microsoft',
#  'hacking',
#  '\xa0cybersecurity',
#  'cybersecurity',
#  'service',
#  'market',
#  'size',
#  'growth',
#  '20212027',
#  'microsoft',
#  'hacking',
#  '\xa0cybersecurity',
#  'trump',
#  'twitter',
#  'hack',
#  'police',
#  'accept',
#  'attacker',
#  'claim',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'report',
#  'telecom',
#  'news',
#  'et',
#  'telecom',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'coronavirus',
#  'live',
#  'india',
#  'see',
#  '80834',
#  'new',
#  'case',
#  'lowest',
#  'spike',
#  '71',
#  'day',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'ransomware',
#  'cartel',
#  'using',
#  'new',
#  'tactic',
#  'extort',
#  'money',
#  'microsoft',
#  'hacking',
#  '\xa0cybersecurity',
#  'communicate',
#  'safely',
#  'lifetime',
#  'encrypted',
#  'email',
#  '200',
#  'microsoft',
#  'hacking',
#  '\xa0cybersecurity',
#  'source',
#  'telecom',
#  'news',
#  'et',
#  'telecom',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'weve',
#  'shown',
#  'time',
#  'strong',
#  'encryption',
#  'put',
#  'crims',
#  'behind',
#  'bar',
#  'politico',
#  'hate',
#  'register',
#  'microsoft',
#  'hacking',
#  '\xa0cybersecurity',
#  'chinese',
#  'hacker',
#  'target',
#  'indian',
#  'vaccine',
#  'maker',
#  'sii',
#  'bharat',
#  'biotech',
#  'say',
#  'security',
#  'firm',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'foreignbound',
#  'student',
#  'welcome',
#  'relaxation',
#  '2nd',
#  'vaccine',
#  'dose',
#  'gap',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'energy',
#  'relation',
#  'sign',
#  'russia',
#  'declining',
#  'global',
#  'standing',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'asiapakistan',
#  'fake',
#  'news',
#  'rape',
#  'religious',
#  'conversion',
#  'christian',
#  'girl',
#  'attack',
#  'church',
#  'damage',
#  'religious',
#  'minority',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'hacker',
#  'stealing',
#  'money',
#  'via',
#  '167',
#  'fake',
#  'trading',
#  'crypto',
#  'apps',
#  'android',
#  'io',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'coronavirus',
#  'african',
#  'sex',
#  'worker',
#  'lack',
#  'food',
#  'hiv',
#  'drug',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'indian',
#  'court',
#  'reject',
#  'plea',
#  'amazon',
#  'flipkart',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'ireland',
#  'warned',
#  'could',
#  'face',
#  'rolling',
#  'blackout',
#  'doesnt',
#  'address',
#  'data',
#  'centre',
#  'demand',
#  'electricity',
#  'register',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'counterpoint',
#  'telecom',
#  'news',
#  'et',
#  'telecom',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'identity',
#  'authentication',
#  'access',
#  'market',
#  'set',
#  'hit',
#  '285bn',
#  '2021',
#  'microsoft',
#  'hacking',
#  '\xa0cybersecurity',
#  'major',
#  'cyberattacks',
#  'rise',
#  'u',
#  'expert',
#  'say',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'hacker',
#  'deface',
#  'facebooks',
#  'official',
#  'twitter',
#  'instagram',
#  'account',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'health',
#  'ministry',
#  'security',
#  'researcher',
#  'deny',
#  'report',
#  'cowin',
#  'data',
#  'breach',
#  'meity',
#  'investigate',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'npr',
#  'cookie',
#  'consent',
#  'choice',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'govt',
#  'official',
#  'data',
#  'exposed',
#  'hacker',
#  'alert',
#  'sent',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'biden',
#  'budget',
#  'seek',
#  'boost',
#  'military',
#  'cyber',
#  'force',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'data',
#  'passwordstealing',
#  'malware',
#  'spreading',
#  'unusual',
#  'way',
#  'microsoft',
#  'hacking',
#  '\xa0cybersecurity',
#  'cowin',
#  'apps',
#  'covid19',
#  'vaccination',
#  'data',
#  '15',
#  'crore',
#  'user',
#  'leaked',
#  'sale',
#  'government',
#  'denies',
#  'breach',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'coronavirus',
#  'live',
#  'chance',
#  'third',
#  'wave',
#  'real',
#  'say',
#  'arvind',
#  'kejriwal',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'blackrock',
#  'greater',
#  'europe',
#  'investment',
#  'trust',
#  'plc',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'cybersecurity',
#  'physical',
#  'security',
#  'device',
#  'government',
#  'hacking',
#  '\xa0cyberattack',
#  'bt',
#  'promise',
#  'firmware',
#  'update',
#  'mini',
#  'whole',
#  'home',
#  'wifi',
#  'disc',
#  'prevent',
#  'obsessive',
#  'big',
#  'tech',
#  'dns',
#  'lookup',
#  'register',
#  'microsoft',
#  'hacking',
#  '\xa0cybersecurity',
#  'got',
#  'infected',
#  'trojanmalware300983susgen',
#  'downloading',
#  'ngrok',
#  'help',
#  'microsoft',
#  'hacking',
#  '\xa0cybersecurity',
#  'jibran',
#  'nasir',
#  'others',
#  'target',
#  'whatsapp',
#  'otp',
#  'scam',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'new',
#  'research',
#  'telia',
#  'carrier',
#  'reveals',
#  'spike',
#  'network',
#  'security',
#  'incident',
#  'driven',
#  'covid19',
#  'pandemic',
#  '20210610',
#  'press',
#  'release',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'column',
#  'virus',
#  'virus',
#  'pandemic',
#  'cyber',
#  'threat',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'mcdonalds',
#  'hit',
#  'data',
#  'hack',
#  'latest',
#  'high',
#  'profile',
#  'attack',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'google',
#  'workspace',
#  'gain',
#  'clientside',
#  'encryption',
#  'amid',
#  'slew',
#  'new',
#  'security',
#  'feature',
#  'microsoft',
#  'hacking',
#  '\xa0cybersecurity',
#  'pakistan',
#  'banking',
#  'sector',
#  'vulnerable',
#  'cyber',
#  'attack',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'fruit',
#  'vendor',
#  'feed',
#  'monkey',
#  'madurai',
#  'amid',
#  'lockdown',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'npr',
#  'cookie',
#  'consent',
#  'choice',
#  'cybersecurity',
#  '\xa0cyberattack',
#  'microsoft',
#  'say',
#  ...]

# %% [markdown]
# ## Small Analysis

# %%
from nltk.probability import FreqDist
fdist = FreqDist()
for word in cs_words:
    fdist[word]+=1
fdist
# Out:
# FreqDist({'cybersecurity': 823, '\xa0cyberattack': 690, 'microsoft': 232, 'hacking': 208, 'cyber': 185, '\xa0cybersecurity': 178, 'attack': 145, 'news': 110, 'security': 106, 'hacker': 89, ...})

# %%
del fdist['cybersecurity'] # removing cybersecurity since all tweets whould have it

# %%
fdist.most_common(10)
# Out:
# [('cybersecurity', 823),
#  ('\xa0cyberattack', 690),
#  ('microsoft', 232),
#  ('hacking', 208),
#  ('cyber', 185),
#  ('\xa0cybersecurity', 178),
#  ('attack', 145),
#  ('news', 110),
#  ('security', 106),
#  ('hacker', 89)]

# %%
len(fdist)
# Out:
# 2188

# %%
freq_data = pd.DataFrame.from_dict(fdist.most_common(20))
freq_data
# Out:
#                  0    1
# 0    cyberattack    690
# 1   microsoft       232
# 2   hacking         208
# 3   cyber           185
# 4    cybersecurity  178
# 5   attack          145
# 6   news            110
# 7   security        106
# 8   hacker          89
# 9   telecom         82
# 10  data            76
# 11  u               75
# 12  pakistan        72
# 13  india           54
# 14  new             50
# 15  say             49
# 16  et              48
# 17  2021            46
# 18  register        44
# 19  ransomware      43

# %%
sns.barplot(data = freq_data, x = 1, y = 0);
