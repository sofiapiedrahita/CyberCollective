# %% [markdown]
# # Cybersecurity_tweets_sofia

# %%
from IPython.display import Image
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
sns.set(rc={'figure.figsize':(6,6)}) 

import warnings
warnings.simplefilter("ignore")

# %matplotlib inline

from sklearn.preprocessing import LabelEncoder 

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

from sklearn import metrics

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate

from sklearn.metrics import SCORERS
import re

# %%
data = pd.read_csv('cybersecurity_tweets.csv')

# %%
data.head()
# Out:
#       user_id             status_id           created_at  screen_name  \
# 0  x109082290  x1404488925935177737  2021-06-14 17:20:28  NcsVentures
# 1  x109082290  x1403635112613494786  2021-06-12 08:47:43  NcsVentures
# 2  x109082290  x1403747937818120198  2021-06-12 16:16:03  NcsVentures
# 3  x109082290  x1404021845913899009  2021-06-13 10:24:28  NcsVentures
# 4  x109082290  x1404053089804554241  2021-06-13 12:28:37  NcsVentures
#
#                                                 text         source  \
# 0  Signs, Causes and Solutions for Network Data B...  WordPress.com
# 1  Battling Chinese Big Tech encroachment in Indi...  WordPress.com
# 2  Ask Dr. Jeanette® Success On “The Way” Devil O...  WordPress.com
# 3  Cyber threats to Digital Pakistan | #cybersecu...  WordPress.com
# 4  Pakistan Cyber Attack News: Pakistan army clai...  WordPress.com
#
#    display_text_width reply_to_status_id reply_to_user_id  \
# 0                 109                NaN              NaN
# 1                 103                NaN              NaN
# 2                 226                NaN              NaN
# 3                  89                NaN              NaN
# 4                 152                NaN              NaN
#
#   reply_to_screen_name  ...  statuses_count  favourites_count  \
# 0                  NaN  ...          260725                 0
# 1                  NaN  ...          260725                 0
# 2                  NaN  ...          260725                 0
# 3                  NaN  ...          260725                 0
# 4                  NaN  ...          260725                 0
#
#     account_created_at  verified              profile_url  \
# 0  2010-01-27 22:48:24     False  https://t.co/E0XpJWVD52
# 1  2010-01-27 22:48:24     False  https://t.co/E0XpJWVD52
# 2  2010-01-27 22:48:24     False  https://t.co/E0XpJWVD52
# 3  2010-01-27 22:48:24     False  https://t.co/E0XpJWVD52
# 4  2010-01-27 22:48:24     False  https://t.co/E0XpJWVD52
#
#                     profile_expanded_url account_lang  \
# 0  http://www.nationalcybersecurity.com/          NaN
# 1  http://www.nationalcybersecurity.com/          NaN
# 2  http://www.nationalcybersecurity.com/          NaN
# 3  http://www.nationalcybersecurity.com/          NaN
# 4  http://www.nationalcybersecurity.com/          NaN
#
#                                   profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/10908229...
# 1  https://pbs.twimg.com/profile_banners/10908229...
# 2  https://pbs.twimg.com/profile_banners/10908229...
# 3  https://pbs.twimg.com/profile_banners/10908229...
# 4  https://pbs.twimg.com/profile_banners/10908229...
#
#                               profile_background_url  \
# 0  http://abs.twimg.com/images/themes/theme15/bg.png
# 1  http://abs.twimg.com/images/themes/theme15/bg.png
# 2  http://abs.twimg.com/images/themes/theme15/bg.png
# 3  http://abs.twimg.com/images/themes/theme15/bg.png
# 4  http://abs.twimg.com/images/themes/theme15/bg.png
#
#                                    profile_image_url
# 0  http://pbs.twimg.com/profile_images/715854922/...
# 1  http://pbs.twimg.com/profile_images/715854922/...
# 2  http://pbs.twimg.com/profile_images/715854922/...
# 3  http://pbs.twimg.com/profile_images/715854922/...
# 4  http://pbs.twimg.com/profile_images/715854922/...
#
# [5 rows x 90 columns]

# %%
df = data[["text", "is_quote", "is_retweet", "retweet_count", "hashtags", "followers_count"]]

# %%
df.head()
# Out:
#                                                 text  is_quote  is_retweet  \
# 0  Signs, Causes and Solutions for Network Data B...     False       False
# 1  Battling Chinese Big Tech encroachment in Indi...     False       False
# 2  Ask Dr. Jeanette® Success On “The Way” Devil O...     False       False
# 3  Cyber threats to Digital Pakistan | #cybersecu...     False       False
# 4  Pakistan Cyber Attack News: Pakistan army clai...     False       False
#
#    retweet_count                   hashtags  followers_count
# 0              0  cybersecurity cyberattack             8524
# 1              4  cybersecurity cyberattack             8524
# 2              3  cybersecurity cyberattack             8524
# 3              2  cybersecurity cyberattack             8524
# 4              2  cybersecurity cyberattack             8524

# %%
import nltk as nl

# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.15.3-py2.py3-none-any.whl (636 kB)
#      |████████████████████████████████| 636 kB 3.2 MB/s eta 0:00:01
# Requirement already satisfied: nltk>=3.1 in /Users/sofiapiedrahita/opt/anaconda3/lib/python3.8/site-packages (from textblob) (3.6.1)
# Requirement already satisfied: regex in /Users/sofiapiedrahita/opt/anaconda3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (2021.4.4)
# Requirement already satisfied: joblib in /Users/sofiapiedrahita/opt/anaconda3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (1.0.1)
# Requirement already satisfied: tqdm in /Users/sofiapiedrahita/opt/anaconda3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (4.59.0)
# Requirement already satisfied: click in /Users/sofiapiedrahita/opt/anaconda3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (7.1.2)
# Installing collected packages: textblob
# Successfully installed textblob-0.15.3

# %%
# !python -m textblob.download_corpora
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     /Users/sofiapiedrahita/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/sofiapiedrahita/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/sofiapiedrahita/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/sofiapiedrahita/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     /Users/sofiapiedrahita/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /Users/sofiapiedrahita/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# Finished.

# %%
cyber = df[["text"]]
pd.set_option('display.max_colwidth', -1)
cyber
# Out:
#                                                                                                                                                                                                                                                                                                   text
# 0      Signs, Causes and Solutions for Network Data Breaches | #cybersecurity | #cyberattack https://t.co/oxotVQ4ogO
# 1      Battling Chinese Big Tech encroachment in India | #cybersecurity | #cyberattack https://t.co/GFXaut9ZXH
# 2      Ask Dr. Jeanette® Success On “The Way” Devil On A Choke Chain! It’s Gonna Be Quick! It’s Gonna Be Sure! It’s Gonna Be Final! – Los Angeles Sentinel | Los Angeles Sentinel | #cybersecurity | #cyberattack https://t.co/0yfsRAdUMk
# 3      Cyber threats to Digital Pakistan | #cybersecurity | #cyberattack https://t.co/Se4ENqeOQT
# 4      Pakistan Cyber Attack News: Pakistan army claims major cyber attack by Indian intel | World News | #cybersecurity | #cyberattack https://t.co/wsnAO20OiG
# ...                                                                                                                                                         ...
# 17949  @MahekMShah I doubt if they even understand d  meaning of cyber security. CyberSec is just a formality dept which exists just for d heck of it. Acknowledgement..their ver of acknowledging: if lucky they'll call u &amp; say..why are you bothered sir..aapka kutch loss hua..nahi na, then..
# 17950  Klaus Mochalski, CEO of @Rhebo_IIot explains why energy substations are particularly susceptible to cyberattacks and what can be done about it. #cybersecurity #cyberattacks #informationsecurity #otsecurity\r\nhttps://t.co/cVr86fFgp3
# 17951  University of Gloucestershire - if you are interested in #CyberSecurity #Computing , #DataScience #MachineLearning #ArtificialIntelligence  please watch this short video about the University of Gloucestershire #COURSES @uniofglos  @C11_Cyber https://t.co/7lOSV36IrQ via @YouTube
# 17952  We're starting to venture back to our headquarters after vaccines. It's good to be back!\r\n\r\n#PKI #PrimeKey #EJBCA #Cybersecurity https://t.co/G6STHg8g87
# 17953  Morley Ivers' blog looks at threat of personal liability for #compliance pros in regulated industries. "CCOs must ensure they have access to needed budget" to ensure a firm is in full compliance - incl. w/ data security. #OS33Workplace #cybersecurity #CCOs\r\nhttps://t.co/FvwqMBUNFx
#
# [17954 rows x 1 columns]

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.stem import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sofiapiedrahita/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def cleanTxt(txt):
    txt = re.sub(r'@[A-Za-z0-9]+', '', txt)
    #txt = re.sub(r'#', '', txt) #removing the # symbol
    txt = re.sub(r'RT[\s]+', '', txt) #removing RT
    txt = re.sub(r'https?:\/\/S+', '', txt)
    txt = re.sub(r'[^\w\s]','', txt) #remove everything except words and space
    txt = re.sub(r'_','', txt) #how to remove underscore as well
    return txt

#cleaning text
cyber['text'] = cyber['text'].apply(cleanTxt)

#show cleaned text
pd.set_option('display.max_colwidth', -1)
cyber
# Out:
#                                                                                                                                                                                                                                                                              text
# 0      signs causes and solutions for network data breaches  cybersecurity  cyberattack httpstcooxotvq4ogo
# 1      battling chinese big tech encroachment in india  cybersecurity  cyberattack httpstcogfxaut9zxh
# 2      ask dr jeanette success on the way devil on a choke chain its gonna be quick its gonna be sure its gonna be final  los angeles sentinel  los angeles sentinel  cybersecurity  cyberattack httpstco0yfsradumk
# 3      cyber threats to digital pakistan  cybersecurity  cyberattack httpstcose4enqeoqt
# 4      pakistan cyber attack news pakistan army claims major cyber attack by indian intel  world news  cybersecurity  cyberattack httpstcowsnao20oig
# ...                                                                                                                                              ...
# 17949   i doubt if they even understand d  meaning of cyber security cybersec is just a formality dept which exists just for d heck of it acknowledgementtheir ver of acknowledging if lucky theyll call u amp saywhy are you bothered siraapka kutch loss huanahi na then
# 17950  klaus mochalski ceo of iiot explains why energy substations are particularly susceptible to cyberattacks and what can be done about it cybersecurity cyberattacks informationsecurity otsecurity\r\nhttpstcocvr86ffgp3
# 17951  university of gloucestershire  if you are interested in cybersecurity computing  datascience machinelearning artificialintelligence  please watch this short video about the university of gloucestershire courses   cyber httpstco7losv36irq via
# 17952  were starting to venture back to our headquarters after vaccines its good to be back\r\n\r\npki primekey ejbca cybersecurity httpstcog6sthg8g87
# 17953  morley ivers blog looks at threat of personal liability for compliance pros in regulated industries ccos must ensure they have access to needed budget to ensure a firm is in full compliance  incl w data security os33workplace cybersecurity ccos\r\nhttpstcofvwqmbunfx
#
# [17954 rows x 1 columns]

# %%
#convert all to lowercase
cyber["text"] = cyber["text"].str.lower()
cyber
# Out:
#                                                                                                                                                                                                                                                                              text
# 0      signs causes and solutions for network data breaches  cybersecurity  cyberattack httpstcooxotvq4ogo
# 1      battling chinese big tech encroachment in india  cybersecurity  cyberattack httpstcogfxaut9zxh
# 2      ask dr jeanette success on the way devil on a choke chain its gonna be quick its gonna be sure its gonna be final  los angeles sentinel  los angeles sentinel  cybersecurity  cyberattack httpstco0yfsradumk
# 3      cyber threats to digital pakistan  cybersecurity  cyberattack httpstcose4enqeoqt
# 4      pakistan cyber attack news pakistan army claims major cyber attack by indian intel  world news  cybersecurity  cyberattack httpstcowsnao20oig
# ...                                                                                                                                              ...
# 17949   i doubt if they even understand d  meaning of cyber security cybersec is just a formality dept which exists just for d heck of it acknowledgementtheir ver of acknowledging if lucky theyll call u amp saywhy are you bothered siraapka kutch loss huanahi na then
# 17950  klaus mochalski ceo of iiot explains why energy substations are particularly susceptible to cyberattacks and what can be done about it cybersecurity cyberattacks informationsecurity otsecurity\r\nhttpstcocvr86ffgp3
# 17951  university of gloucestershire  if you are interested in cybersecurity computing  datascience machinelearning artificialintelligence  please watch this short video about the university of gloucestershire courses   cyber httpstco7losv36irq via
# 17952  were starting to venture back to our headquarters after vaccines its good to be back\r\n\r\npki primekey ejbca cybersecurity httpstcog6sthg8g87
# 17953  morley ivers blog looks at threat of personal liability for compliance pros in regulated industries ccos must ensure they have access to needed budget to ensure a firm is in full compliance  incl w data security os33workplace cybersecurity ccos\r\nhttpstcofvwqmbunfx
#
# [17954 rows x 1 columns]
